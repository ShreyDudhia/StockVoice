# %%
from GoogleNews import GoogleNews
from newsfetch.news import newspaper
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import reuters, stopwords
import pandas as pd
import nltk
# nltk.download('stopwords')
googlenews = GoogleNews()
googlenews.set_lang('en')
# googlenews.set_period('365d')
googlenews.set_time_range('01/01/2020','12/03/2020')
googlenews.set_encode('utf-8')
googlenews.search('election')
all_articles = {"article": []}
# for i in googlenews.get_links():
#     search = newspaper(link)
#     all_articles.append(search.article)
# #     break
# print(all_articles[1:2])
googlenews.get_page(40)
googlenews.results()
# Out:
# [{'title': 'Georgia election: All you need to know about key Senate runoff races',
#   'media': 'BBC News',
#   'date': '9 hours ago',
#   'datetime': datetime.datetime(2021, 1, 4, 11, 53, 52, 281232),
#   'desc': 'All eyes are on Georgia as the traditionally Republican state could hand Joe Biden the US Senate.',
#   'link': 'https://www.bbc.com/news/election-us-2020-55489392',
#   'img': '...'},
#  {'title': 'Tracking Viral Misinformation: Latest Updates',
#   'media': 'The New York Times',
#   'date': 'Sep 16, 2020',
#   'datetime': datetime.datetime(2020, 9, 16, 0, 0),
#   'desc': 'Every day, Times reporters will chronicle and debunk false and misleading information that is going viral online. Jan. 3, 2021, 8:34 p.m. ET2h ago. 2h ago.',
#   'link': 'https://www.nytimes.com/live/2020/2020-election-misinformation-distortions',
#   'img': '...'},
#  {'title': 'Paul Ryan denounces plan to reject election results led by Ted Cruz and Ron Johnson',
#   'media': 'Journal Times',
# ...

# %%
for i in range(5):
    googlenews = GoogleNews()
    googlenews.set_lang('en')
    # googlenews.set_period('365d')
    googlenews.set_time_range('01/01/2020','12/03/2020')
    googlenews.set_encode('utf-8')
    googlenews.search('virus')
    all_articles = {"article": []}
    googlenews.get_page(i)
    res = googlenews.result()
    print(res)
#     for article in range(10):
#     page[0]
# Out:
# [{'title': "The memory of SARS looms over the Wuhan virus. Here's how the outbreaks compare", 'media': 'CNN', 'date': 'Feb 2, 2020', 'datetime': datetime.datetime(2020, 2, 2, 0, 0), 'desc': "Hong Kong (CNN) The Wuhan coronavirus has sparked alarm around the world, but in Asia, it's also brought up memories of a deadly virus. To many, the latest ...", 'link': 'https://www.cnn.com/2020/01/29/china/sars-wuhan-virus-explainer-intl-hnk-scli/index.html', 'img': '...'}, {'title': 'China confirms Wuhan virus can be spread by humans', 'media': 'CNN', 'date': 'Jan 22, 2020', 'datetime': datetime.datetime(2020, 1, 22, 0, 0), 'desc': 'The spread of the respiratory virus to Thailand, Japan, South Korea, Taiwan, and now the United States, is fueling fears of a broader epidemic, as China enters its ...', 'link': 'https://www.cnn.com/2020/01/21/asia/china-china-coronavirus-sars-intl-hnk/index.html', 'img': '...'}, {'title': 'The Wuhan Virus: How to Stay Safe', 'media': 'Foreign Policy', 'date': 'Jan
# ...

# %%
# google1 = googlenews.get_news('corona')
google_test = googlenews.search('corona')
# googlenews.get_page(1)
print(google1)
# Out:
# None

# %%
def process_text(article):
    sw = set(stopwords.words('english'))
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub(' ', article)
    words = word_tokenize(re_clean)
    lem = [lemmatizer.lemmatize(word) for word in words]
    output = [word.lower() for word in lem if word.lower() not in sw]
    return output

# %%
process_text(all_articles)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-0abdb45f0bd7> in <module>
# ----> 1 process_text(all_articles)
#
# <ipython-input-28-4e0110385933> in process_text(article)
#       2     sw = set(stopwords.words('english'))
#       3     regex = re.compile("[^a-zA-Z ]")
# ----> 4     re_clean = regex.sub(' ', article)
#       5     words = word_tokenize(re_clean)
#       6     lem = [lemmatizer.lemmatize(word) for word in words]
#
# TypeError: expected string or bytes-like object
