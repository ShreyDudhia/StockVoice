# %%
from GoogleNews import GoogleNews
googlenews = GoogleNews()

# %%
listOfArticles = []
for i in range(20):
    googlenews = GoogleNews()
    googlenews.set_lang('en')
    # googlenews.set_period('365d')
    googlenews.set_time_range('01/01/2020','12/03/2020')
    googlenews.set_encode('utf-8')
    googlenews.search('virus')
    all_articles = {"article": []}
    googlenews.get_page(i)
    res = googlenews.result(sort=True)
    listOfArticles.append(res)
listOfArticles
# Out:
# [[{'title': 'U.S. Soldier Tests Positive for Virus in South Korea',
#    'media': 'The New York Times',
#    'date': 'Mar 13, 2020',
#    'datetime': datetime.datetime(2020, 3, 13, 0, 0),
#    'desc': 'U.S. Soldier Tests Positive for Virus in South Korea. The soldier, the first U.S. service member known to be infected, has been quarantined in his off-base residence ...',
#    'link': 'https://www.nytimes.com/2020/02/25/world/asia/coronavirus-news.html',
#    'img': '...'},
#   {'title': 'U.S. Soldier Tests Positive for Virus in South Korea',
#    'media': 'The New York Times',
#    'date': 'Mar 13, 2020',
#    'datetime': datetime.datetime(2020, 3, 13, 0, 0),
#    'desc': 'U.S. Soldier Tests Positive for Virus in South Korea. The soldier, the first U.S. service member known to be infected, has been quarantined in his off-base residence ...',
#    'link': 'https://www.nytimes.com/2020/02/25/world/asia/coronavirus-news.html',
#    'img': '...'},
# ...

# %%
# Custom sorting
size = len(listOfArticles)
for i in range(size):
    min_index = i
    for j in range(i + 1, size):
        if csv_mapping_list[min_index]["Age"] > csv_mapping_list[j]["Age"]:
            min_index = j
    csv_mapping_list[i], csv_mapping_list[min_index] = csv_mapping_list[min_index], csv_mapping_list[i]
